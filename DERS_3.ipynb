# %%
from google.colab import drive # google colab  - drive bağlantısı
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.chdir('/content/drive/My Drive/yapayzekacalismalarim-igu')

# !pwd # bize kodun çıktısını dosya yolu olarak veren kod blogudur
# Out:
# /content/drive/My Drive/yapayzekacalismalarim-igu

# %% [markdown]
# BeatifulSoup
# İnternet sayfasından başlıkları(h1,h2,h3)alır ve ekran yazdırır

# %%
import requests
from bs4 import BeautifulSoup

#web sayfasının url si
url = 'https://www.ozkanyapiinsaat.net/'

#web sayfasını indir
response = requests.get(url)

#Eğer bağlantı başarılıysa
if response.status_code == 200:
# HTML içeriğini ayrıştır
  soup = BeautifulSoup(response.content, 'html.parser')

# Örnek olarak sayfadaki tüm başlıkları (h1,h2,h3 vb.) çek
for heading in soup.find_all(['h1', 'h2', 'h3' ]):
      print(heading.text.strip())
else:
      print("Bağlantı başarısız: ", response.status_code)
# Out:
# Kazandıran projeler, yüz güldüren fiyatlara!
# Kiracı bulmakla ve bina sorunları ile uğraşmayın!
# Yatırım için ortaklık mı arıyorsunuz?
# Proje Vitrini
# Eskihisar Projesi
# Mutlukent Projesi
# Barış Projesi
# Köşklü Çeşme Projesi
# Yıldız Projesi
# Adliye Önü Projesi
# Haberler
# Yeni Projelerimize Girişimci Olarak Katılabilirsiniz!
# Eskihisar ve Mutlukent Projelerimiz Başladı!
# Gebze Metrosunun Güzergahı ve İstasyonları Belli Oldu
# Gebze Hakkında
# Özkan Yapı Tanıtım Videosu
# Özkan Yapı
# Müşterilerimizden
# Mehmet Uyanmaz
# İzzet Yıldız
# Muhammet Kankal
# Nevzat İşler
# Hasan Demirtaş
# Hasan Dokuz
# Sinan Güneş ve Mehmet Coşkun
# Kurumsal
# İletişim
# Bağlantı başarısız:  200

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ozkanyapiinsaat.net/'

response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')

    links = soup.find_all('a')

    for link in links:
        href = link.get('href')
        text = link.text.strip()
        if href:
            print("Bağlantı metni: ", text, "URL:", href)
    print("Toplam bulunan bilgi sayısı: ", len(links), " adet")
else:
    print("Bağlantı başarısız: ", response.status_code)
# Out:
# Bağlantı metni:   URL: https://www.ozkanyapiinsaat.net
# Bağlantı metni:  Ana Sayfa URL: https://www.ozkanyapiinsaat.net/
# Bağlantı metni:  Hakkımızda URL: https://www.ozkanyapiinsaat.net/hakkimizda/
# Bağlantı metni:  Projelerimiz URL: #
# Bağlantı metni:  Yeni Projeler URL: https://www.ozkanyapiinsaat.net/project-category/yeni-projeler/
# Bağlantı metni:  Tamamlanan Projeler URL: https://www.ozkanyapiinsaat.net/project-category/tamamlanan-projeler/
# Bağlantı metni:  Hizmetlerimiz URL: #
# Bağlantı metni:  Konut Satışı URL: https://www.ozkanyapiinsaat.net/konut-satisi/
# Bağlantı metni:  Konut Kiralama ve Yönetim URL: https://www.ozkanyapiinsaat.net/konut-kiralama-ve-yonetim/
# Bağlantı metni:  İş Ortaklığı / Müşterek Girişim URL: https://www.ozkanyapiinsaat.net/is-ortakligi-musterek-girisim/
# Bağlantı metni:  İletişim URL: https://www.ozkanyapiinsaat.net/iletisim/
# Bağlantı metni:   URL: https://www.ozkanyapiinsaat.net/
# Bağlantı metni:   URL: https://www.ozkanyapiinsaat.net/en/
# Bağlantı metni:   URL: https://www.ozkanyapiinsaat.net/
# Bağlantı metni:  Ana Sayfa URL: https://www.ozkanyapiinsaat.net/
# Bağlantı metni:  Hakkımızda URL: https://www.ozkanyapiinsaat.net/hakkimizda/
# Bağlantı metni:  Projelerimiz URL: #
# Bağlantı metni:  Yeni Projeler URL: https://www.ozkanyapiinsaat.net/project-category/yeni-projeler/
# Bağlantı metni:  Tamamlanan Projeler URL: https://www.ozkanyapiinsaat.net/project-category/tamamlanan-projeler/
# Bağlantı metni:  Hizmetlerimiz URL: #
# Bağlantı metni:  Konut Satışı URL: https://www.ozkanyapiinsaat.net/konut-satisi/
# Bağlantı metni:  Konut Kiralama ve Yönetim URL: https://www.ozkanyapiinsaat.net/konut-kiralama-ve-yonetim/
# Bağlantı metni:  İş Ortaklığı / Müşterek Girişim URL: https://www.ozkanyapiinsaat.net/is-ortakligi-musterek-girisim/
# Bağlantı metni:  İletişim URL: https://www.ozkanyapiinsaat.net/iletisim/
# Bağlantı metni:   URL: https://www.ozkanyapiinsaat.net/
# Bağlantı metni:   URL: https://www.ozkanyapiinsaat.net/en/
# Bağlantı metni:   URL: javascript:void(0)
# Bağlantı metni:  Detaylı Bilgi URL: https://www.ozkanyapiinsaat.net/kazandiran-projeler-yuz-gulduren-fiyatlara/
# Bağlantı metni:  Detaylı Bilgi URL: https://www.ozkanyapiinsaat.net/konut-kiralama-ve-yonetim/
# Bağlantı metni:  Detaylı Bilgi URL: https://www.ozkanyapiinsaat.net/is-ortakligi-musterek-girisim/
# Bağlantı metni:  Detaylı Bilgi URL: #
# Bağlantı metni:   URL: https://www.ozkanyapiinsaat.net/project/eskihisar-projesi/
# Bağlantı metni:  Detaylı Bilgi URL: #
# Bağlantı metni:   URL: https://www.ozkanyapiinsaat.net/project/mutlukent-projesi/
# Bağlantı metni:  Detaylı Bilgi URL: #
# Bağlantı metni:   URL: https://www.ozkanyapiinsaat.net/project/baris-projesi/
# Bağlantı metni:  Detaylı Bilgi URL: #
# Bağlantı metni:   URL: https://www.ozkanyapiinsaat.net/project/kosklu-cesme-projesi/
# Bağlantı metni:  Detaylı Bilgi URL: #
# Bağlantı metni:   URL: https://www.ozkanyapiinsaat.net/project/yildiz-projesi/
# Bağlantı metni:  Detaylı Bilgi URL: #
# Bağlantı metni:   URL: https://www.ozkanyapiinsaat.net/project/adliye-onu-projesi/
# Bağlantı metni:   URL: https://www.ozkanyapiinsaat.net/yeni-projelerimize-girisimci-olarak-katilabilirsiniz/
# Bağlantı metni:  Yeni Projelerimize Girişimci Olarak Katılabilirsiniz! URL: https://www.ozkanyapiinsaat.net/yeni-projelerimize-girisimci-olarak-katilabilirsiniz/
# Bağlantı metni:   URL: https://www.ozkanyapiinsaat.net/eskihisar-ve-mutlukent-projelerimiz-cok-yakinda-basliyor/
# Bağlantı metni:  Eskihisar ve Mutlukent Projelerimiz Başladı! URL: https://www.ozkanyapiinsaat.net/eskihisar-ve-mutlukent-projelerimiz-cok-yakinda-basliyor/
# Bağlantı metni:   URL: https://www.ozkanyapiinsaat.net/gebze-metrosunun-guzergahi-ve-istasyonlari-belli-oldu/
# Bağlantı metni:  Gebze Metrosunun Güzergahı ve İstasyonları Belli Oldu URL: https://www.ozkanyapiinsaat.net/gebze-metrosunun-guzergahi-ve-istasyonlari-belli-oldu/
# Bağlantı metni:   URL: https://www.ozkanyapiinsaat.net/gebze-hakkinda/
# Bağlantı metni:  Gebze Hakkında URL: https://www.ozkanyapiinsaat.net/gebze-hakkinda/
# Bağlantı metni:   URL: https://www.ozkanyapiinsaat.net/ozkan-yapi-tanitim-videosu/
# Bağlantı metni:  Özkan Yapı Tanıtım Videosu URL: https://www.ozkanyapiinsaat.net/ozkan-yapi-tanitim-videosu/
# Bağlantı metni:  Hakkımızda URL: https://www.ozkanyapiinsaat.net/hakkimizda/
# Bağlantı metni:  Hakkımızda URL: https://www.ozkanyapiinsaat.net/hakkimizda/
# Bağlantı metni:  Yeni Projeler URL: https://www.ozkanyapiinsaat.net/project-category/yeni-projeler/
# Bağlantı metni:  Tamamlanan Projeler URL: https://www.ozkanyapiinsaat.net/project-category/tamamlanan-projeler/
# Bağlantı metni:  Konut Satışı URL: https://www.ozkanyapiinsaat.net/konut-satisi/
# Bağlantı metni:  Konut Kiralama ve Yönetim URL: https://www.ozkanyapiinsaat.net/konut-kiralama-ve-yonetim/
# Bağlantı metni:  İş Ortaklığı / Müşterek Girişim URL: https://www.ozkanyapiinsaat.net/is-ortakligi-musterek-girisim/
# Bağlantı metni:  İletişim URL: https://www.ozkanyapiinsaat.net/iletisim/
# Bağlantı metni:  +90 262 642 8131 URL: tel:+90 262 642 8131
# Bağlantı metni:  +90 532 777 8303 URL: tel:+90 532 777 8303
# Bağlantı metni:  info@ozkanyapiinsaat.net URL: mailto:info@ozkanyapiinsaat.net
# Bağlantı metni:   URL: http://www.monarkdigital.com
# Toplam bulunan bilgi sayısı:  64  adet

# %%
# Görüntü İşleme uygulamaları İçin gerekli OPENCV kütüphanesinin yükleme işlemi

# !pip install opencv-python-headless
# Out:
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python-headless) (1.26.4)

# %%
import os
import cv2
import matplotlib.pyplot as plt

# %%
klasor_yolu = '/content/drive/My Drive/yapayzekacalismalarim-igu/opencv_ornekleri'

# %%
resim_formatlari = ('.png', '.jpg', '.jpeg', '.bmp', '.gif', '.tiff')

# %%
islenen_bilgi = [f for f in os.listdir(klasor_yolu) if f.lower().endswith(resim_formatlari)]

print(f"Klasörde ", len(islenen_bilgi), "tane resim var.")

print("Resim dosyalarının isimleri ve dosya uzantıları")

for i in islenen_bilgi:
    print(i)
# Out:
# Klasörde  7 tane resim var.
# Resim dosyalarının isimleri ve dosya uzantıları
# pythonopencvrenkli.png
# python2.png
# python3.png
# trafik-1.png
# trafik-2.png
# trafik-3.png
# python.png

# %%
image = cv2.imread('opencv_ornekleri/trafik-3.png')

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("Yüklenen Görüntünün Gösterimi")
plt.show()
